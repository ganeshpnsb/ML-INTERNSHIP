# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshpnsb/ML-INTERNSHIP/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ganeshpnsb/ML-INTERNSHIP/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose **Lane 2: Refresh / Content Opportunity Scoring**. The goal of this lane is to identify which pages should be reviewed first for content refresh based on observable search and content signals. I chose this lane because it matches the starter notebooks and helps SEO teams prioritize pages using evidence rather than intuition. Machine learning can rank pages more effectively by considering multiple signals together.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## 2. The Question: Decision, Action, Cost of a Wrong Call
#
# **Decision:** Which content pages should be reviewed first for refresh?
#
# **Unit of analysis:** One content page.
#
# **Output:** A ranked list of pages with refresh priority scores.
#
# **Action:** SEO teams can update or improve the highest-priority pages before reviewing lower-priority ones.
#
# **Cost of a wrong recommendation:** Missing a truly declining page could lead to continued traffic loss, while recommending a healthy page wastes time and resources.
#
# **Why ML helps:** Machine learning can combine multiple observable signals to prioritize pages more accurately than simple rule-based methods.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/ganeshpnsb/ML-INTERNSHIP"
REPO_DIR = "ML-INTERNSHIP"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

print(os.getcwd())
# Out:
# /content/ML-INTERNSHIP/ML-INTERNSHIP

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total Pages:", df.shape[0])
print("Total Columns:", df.shape[1])

print("\nTrend Direction Distribution:")
print(df["trend_direction"].value_counts())

print("\nAverage Search Volume:", round(df["search_volume"].mean(), 2))
print("Average Impressions:", round(df["impressions_90d"].mean(), 2))
# Out:
# Total Pages: 30000
# Total Columns: 44
#
# Trend Direction Distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average Search Volume: 158.88
# Average Impressions: 5200.37

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## 4. Careful Words: What I Can and Can't Claim
#
# This project identifies patterns observed in the anonymized dataset and provides decision support for prioritizing content reviews. The results do not prove how Google's ranking algorithm works, nor do they guarantee that refreshing a page will improve its performance. The recommendations are based on observed evidence and should always be reviewed by humans before taking action.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [Y] Every section above is filled — markdown thinking AND the code that backs it
# - [Y] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [Y] No client names, URLs, or private queries anywhere
# - [Y] My claims use careful words: observed, measured, directional, decision-support
# - [Y] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
